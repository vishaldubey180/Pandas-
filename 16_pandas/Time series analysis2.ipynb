# %% [markdown]
# ## Time series analysis 2

# %%
import pandas as pd

# %%
df = pd.read_csv('aapl_no_dates.csv')

# %%
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
# So here we can see that we don't have date column for given dataset now we have to handle this

# %%
# we have to call daterange

# %%
rng = pd.date_range(start='1/1/2021', end='2/1/2021', freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-18',
#                '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-02-01'],
#               dtype='datetime64[ns]', freq='B')

# %%
# Now we have created this indexes and we have to apply on our dataframe

# %%
df.set_index(rng,inplace=True)

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2021-01-01  153.17  153.33  152.22  153.18  16404088
# 2021-01-04  153.58  155.45  152.89  155.45  27770715
# 2021-01-05  154.34  154.45  153.46  153.93  25331662
# 2021-01-06  153.90  155.81  153.78  154.45  26624926
# 2021-01-07  155.02  155.98  154.48  155.37  21069647
# 2021-01-08  155.25  155.54  154.40  154.99  21250798
# 2021-01-11  155.19  155.19  146.02  148.98  64882657
# 2021-01-12  145.74  146.09  142.51  145.42  72307330
# 2021-01-13  147.16  147.45  145.15  146.59  34165445
# 2021-01-14  147.50  147.50  143.84  145.16  31531232
# 2021-01-15  143.32  144.48  142.21  144.29  32165373
# 2021-01-18  143.78  144.50  142.20  142.27  50361093
# 2021-01-19  143.66  146.74  143.66  146.34  32541404
# 2021-01-20  146.87  146.87  144.94  145.01  24900073
# 2021-01-21  145.52  146.07  144.61  145.87  21265751
# 2021-01-22  145.77  146.70  145.12  145.63  19106294
# 2021-01-25  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# we can plot a chart of closing price

# %%
# %matplotlib inline

# %%
df.Close.plot()

# %%
# we can see data in range also

# %%
df['1-1-2021':'1-14-2021']
# Out:
#               Open    High     Low   Close    Volume
# 2021-01-01  153.17  153.33  152.22  153.18  16404088
# 2021-01-04  153.58  155.45  152.89  155.45  27770715
# 2021-01-05  154.34  154.45  153.46  153.93  25331662
# 2021-01-06  153.90  155.81  153.78  154.45  26624926
# 2021-01-07  155.02  155.98  154.48  155.37  21069647
# 2021-01-08  155.25  155.54  154.40  154.99  21250798
# 2021-01-11  155.19  155.19  146.02  148.98  64882657
# 2021-01-12  145.74  146.09  142.51  145.42  72307330
# 2021-01-13  147.16  147.45  145.15  146.59  34165445
# 2021-01-14  147.50  147.50  143.84  145.16  31531232

# %%
df['1-1-2021':'2-1-2021'].Close
# Out:
# 2021-01-01    153.18
# 2021-01-04    155.45
# 2021-01-05    153.93
# 2021-01-06    154.45
# 2021-01-07    155.37
# 2021-01-08    154.99
# 2021-01-11    148.98
# 2021-01-12    145.42
# 2021-01-13    146.59
# 2021-01-14    145.16
# 2021-01-15    144.29
# 2021-01-18    142.27
# 2021-01-19    146.34
# 2021-01-20    145.01
# 2021-01-21    145.87
# 2021-01-22    145.63
# 2021-01-25    146.28
# 2021-01-26    145.82
# 2021-01-27    143.73
# 2021-01-28    145.83
# 2021-01-29    143.68
# 2021-02-01    144.02
# Freq: B, Name: Close, dtype: float64

# %%
df['1-1-2021':'2-1-2021'].Close.mean()
# Out:
# 147.83136363636365

# %%
# %matplotlib inline

df['1-1-2021':'2-1-2021'].Close.plot()

# %%
# if we want sat and sunday also in dataframe

# %%
df.asfreq('D') # as freq allows us to generate our data on cnoditions
# Out:
#               Open    High     Low   Close      Volume
# 2021-01-01  153.17  153.33  152.22  153.18  16404088.0
# 2021-01-02     NaN     NaN     NaN     NaN         NaN
# 2021-01-03     NaN     NaN     NaN     NaN         NaN
# 2021-01-04  153.58  155.45  152.89  155.45  27770715.0
# 2021-01-05  154.34  154.45  153.46  153.93  25331662.0
# 2021-01-06  153.90  155.81  153.78  154.45  26624926.0
# 2021-01-07  155.02  155.98  154.48  155.37  21069647.0
# 2021-01-08  155.25  155.54  154.40  154.99  21250798.0
# 2021-01-09     NaN     NaN     NaN     NaN         NaN
# 2021-01-10     NaN     NaN     NaN     NaN         NaN
# 2021-01-11  155.19  155.19  146.02  148.98  64882657.0
# 2021-01-12  145.74  146.09  142.51  145.42  72307330.0
# 2021-01-13  147.16  147.45  145.15  146.59  34165445.0
# 2021-01-14  147.50  147.50  143.84  145.16  31531232.0
# 2021-01-15  143.32  144.48  142.21  144.29  32165373.0
# 2021-01-16     NaN     NaN     NaN     NaN         NaN
# ...

# %%
# Here on sat and sundays data is missing we can use pad method

# %%
df.asfreq('B', method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2021-01-01  153.17  153.33  152.22  153.18  16404088
# 2021-01-04  153.58  155.45  152.89  155.45  27770715
# 2021-01-05  154.34  154.45  153.46  153.93  25331662
# 2021-01-06  153.90  155.81  153.78  154.45  26624926
# 2021-01-07  155.02  155.98  154.48  155.37  21069647
# 2021-01-08  155.25  155.54  154.40  154.99  21250798
# 2021-01-11  155.19  155.19  146.02  148.98  64882657
# 2021-01-12  145.74  146.09  142.51  145.42  72307330
# 2021-01-13  147.16  147.45  145.15  146.59  34165445
# 2021-01-14  147.50  147.50  143.84  145.16  31531232
# 2021-01-15  143.32  144.48  142.21  144.29  32165373
# 2021-01-18  143.78  144.50  142.20  142.27  50361093
# 2021-01-19  143.66  146.74  143.66  146.34  32541404
# 2021-01-20  146.87  146.87  144.94  145.01  24900073
# 2021-01-21  145.52  146.07  144.61  145.87  21265751
# 2021-01-22  145.77  146.70  145.12  145.63  19106294
# 2021-01-25  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# we can see weekely prices also

# %%
df.asfreq('W', method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2021-01-03  153.17  153.33  152.22  153.18  16404088
# 2021-01-10  155.25  155.54  154.40  154.99  21250798
# 2021-01-17  143.32  144.48  142.21  144.29  32165373
# 2021-01-24  145.77  146.70  145.12  145.63  19106294
# 2021-01-31  144.71  145.13  142.28  143.68  31499368

# %%
df.asfreq('H', method='pad')
# Out:
#                        Open    High     Low   Close    Volume
# 2021-01-01 00:00:00  153.17  153.33  152.22  153.18  16404088
# 2021-01-01 01:00:00  153.17  153.33  152.22  153.18  16404088
# 2021-01-01 02:00:00  153.17  153.33  152.22  153.18  16404088
# 2021-01-01 03:00:00  153.17  153.33  152.22  153.18  16404088
# 2021-01-01 04:00:00  153.17  153.33  152.22  153.18  16404088
# ...                     ...     ...     ...     ...       ...
# 2021-01-31 20:00:00  144.71  145.13  142.28  143.68  31499368
# 2021-01-31 21:00:00  144.71  145.13  142.28  143.68  31499368
# 2021-01-31 22:00:00  144.71  145.13  142.28  143.68  31499368
# 2021-01-31 23:00:00  144.71  145.13  142.28  143.68  31499368
# 2021-02-01 00:00:00  144.45  144.96  143.78  144.02  23024107
#
# [745 rows x 5 columns]

# %%
# we know only start date but we don't know the end date but we know number of rows

# %%
rng = pd.date_range(start='1/1/2021', periods=22, freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07', '2021-01-08', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-18',
#                '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-02-01'],
#               dtype='datetime64[ns]', freq='B')

# %%
rng = pd.date_range(start='1/1/2021', periods=22, freq='H')

# %%
rng
# Out:
# DatetimeIndex(['2021-01-01 00:00:00', '2021-01-01 01:00:00',
#                '2021-01-01 02:00:00', '2021-01-01 03:00:00',
#                '2021-01-01 04:00:00', '2021-01-01 05:00:00',
#                '2021-01-01 06:00:00', '2021-01-01 07:00:00',
#                '2021-01-01 08:00:00', '2021-01-01 09:00:00',
#                '2021-01-01 10:00:00', '2021-01-01 11:00:00',
#                '2021-01-01 12:00:00', '2021-01-01 13:00:00',
#                '2021-01-01 14:00:00', '2021-01-01 15:00:00',
#                '2021-01-01 16:00:00', '2021-01-01 17:00:00',
#                '2021-01-01 18:00:00', '2021-01-01 19:00:00',
#                '2021-01-01 20:00:00', '2021-01-01 21:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# we can genrate false data also for sample or experiment purpose

# %%
import numpy as np

# %%
np.random.randint(1,10,len(rng))
# Out:
# array([8, 5, 3, 3, 3, 5, 7, 1, 3, 9, 9, 9, 8, 6, 4, 1, 8, 6, 8, 7, 5, 1])

# %%
s = pd.Series(np.random.randint(1,10,len(rng)), index=rng)

# %%
s
# Out:
# 2021-01-01 00:00:00    5
# 2021-01-01 01:00:00    9
# 2021-01-01 02:00:00    1
# 2021-01-01 03:00:00    1
# 2021-01-01 04:00:00    7
# 2021-01-01 05:00:00    9
# 2021-01-01 06:00:00    7
# 2021-01-01 07:00:00    3
# 2021-01-01 08:00:00    7
# 2021-01-01 09:00:00    9
# 2021-01-01 10:00:00    7
# 2021-01-01 11:00:00    6
# 2021-01-01 12:00:00    1
# 2021-01-01 13:00:00    9
# 2021-01-01 14:00:00    7
# 2021-01-01 15:00:00    9
# 2021-01-01 16:00:00    4
# 2021-01-01 17:00:00    5
# 2021-01-01 18:00:00    8
# 2021-01-01 19:00:00    9
# 2021-01-01 20:00:00    4
# 2021-01-01 21:00:00    8
# Freq: H, dtype: int32
